# %% [markdown]
# <a href="https://colab.research.google.com/github/Shashank-2004/Algorithms-and-Problem-Solving/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
import heapq

def dijkstra(graph, start):
    distances = {node: float('inf') for node in graph}
    distances[start] = 0
    previous = {node: None for node in graph}
    pq = [(0, start)]

    while pq:
        current_distance, current_node = heapq.heappop(pq)

        if current_distance > distances[current_node]:
            continue

        for neighbor, weight in graph[current_node].items():
            distance = current_distance + weight
            if distance < distances[neighbor]:
                distances[neighbor] = distance
                previous[neighbor] = current_node
                heapq.heappush(pq, (distance, neighbor))

    return distances, previous

def shortest_path(previous, start, end):
    path = []
    current = end
    while current is not None:
        path.append(current)
        current = previous[current]
    path.reverse()
    return path

graph = {
    'A': {'B': 4, 'C': 2},
    'B': {'A': 4, 'C': 1, 'D': 5},
    'C': {'A': 2, 'B': 1, 'D': 8, 'E': 10},
    'D': {'B': 5, 'C': 8, 'E': 2},
    'E': {'C': 10, 'D': 2}
}

graph['F'] = {'D': 6, 'E': 3}
graph['G'] = {'F': 1, 'C': 7}

for source in ['A', 'C', 'F']:
    distances, previous = dijkstra(graph, source)
    print(f"\nSource: {source}")
    for target in graph.keys():
        if target != source:
            path = shortest_path(previous, source, target)
            print(f"Shortest path {source} -> {target}: {path}, Distance = {distances[target]}")
# Out:
# Source: A
# Shortest path A -> B: ['A', 'C', 'B'], Distance = 3
# Shortest path A -> C: ['A', 'C'], Distance = 2
# Shortest path A -> D: ['A', 'C', 'B', 'D'], Distance = 8
# Shortest path A -> E: ['A', 'C', 'B', 'D', 'E'], Distance = 10
# Shortest path A -> F: ['F'], Distance = inf
# Shortest path A -> G: ['G'], Distance = inf
#
# Source: C
# Shortest path C -> A: ['C', 'A'], Distance = 2
# Shortest path C -> B: ['C', 'B'], Distance = 1
# Shortest path C -> D: ['C', 'B', 'D'], Distance = 6
# Shortest path C -> E: ['C', 'B', 'D', 'E'], Distance = 8
# Shortest path C -> F: ['F'], Distance = inf
# Shortest path C -> G: ['G'], Distance = inf
#
# Source: F
# Shortest path F -> A: ['F', 'E', 'D', 'B', 'C', 'A'], Distance = 13
# Shortest path F -> B: ['F', 'E', 'D', 'B'], Distance = 10
# Shortest path F -> C: ['F', 'E', 'D', 'B', 'C'], Distance = 11
# Shortest path F -> D: ['F', 'E', 'D'], Distance = 5
# Shortest path F -> E: ['F', 'E'], Distance = 3
# Shortest path F -> G: ['G'], Distance = inf

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.
