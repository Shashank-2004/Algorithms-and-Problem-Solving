# %% [markdown]
# <a href="https://colab.research.google.com/github/Shashank-2004/Algorithms-and-Problem-Solving/blob/main/Lab_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MATRIX CHAIN MULTIPLICATION Dynamic Programming with table filling.
# Problem Description:
# Find minimum number of scalar multiplications needed to multiply a chain of matrices..

# %% [markdown]
# #Theory
# Cost of multiplying two matrices:
# If A is p×q and B is q×r, cost = p × q × r
#
# Dynamic Programming idea:
# Break problem into smaller subproblems.
# Store results in a table to avoid recomputation.
#
# m[i][j] = minimum cost to multiply Ai to Aj
#
# ## Algorithm
# 1. Take array p[] of size n
# 2. Create table m[n][n]
# 3. Set m[i][i] = 0
# 4. Fill table diagonally
# 5. For each chain length L:
#     Compute m[i][j]
#     Try all possible k between i and j
# 6. Choose minimum cost
# 7. Return m[1][n-1]

# %%
import sys

def matrix_chain_order(p):
    n = len(p)
    m = [[0 for _ in range(n)] for _ in range(n)]
    for L in range(2, n):
        for i in range(1, n - L + 1):
            j = i + L - 1
            m[i][j] = sys.maxsize
            for k in range(i, j):
                q = m[i][k] + m[k+1][j] + p[i-1] * p[k] * p[j]
                if q < m[i][j]:
                    m[i][j] = q

    return m
p = [10, 20, 30, 40, 30]
m = matrix_chain_order(p)

print("Minimum number of multiplications:", m[1][len(p)-1])

print("\nDP Table:")
for row in m[1:len(p)]:
    print(row[1:len(p)])
# Out:
# Minimum number of multiplications: 30000
#
# DP Table:
# [0, 6000, 18000, 30000]
# [0, 0, 24000, 48000]
# [0, 0, 0, 36000]
# [0, 0, 0, 0]

# %%
# Input dimensions
p = [10, 30, 5, 60]

table = matrix_chain_order(p)

print("Minimum multiplication cost:", table[1][len(p)-1])

print("\nDP Table:")
for row in table[1:]:
    print(row[1:])
# Out:
# Minimum multiplication cost: [0, 0, 0, 0]
#
# DP Table:
# [[0, 0, 1, 2], [0, 0, 0, 2], [0, 0, 0, 0]]

# %% [markdown]
# # Exercise
# 1. Given p = [5, 10, 3, 12, 5, 50, 6]
# 2. Compute minimum cost
# 3. Print optimal parenthesization
# 4. Compare number of multiplications saved

# %%
import sys

def matrix_chain_order(p):
    n = len(p)
    m = [[0 for _ in range(n)] for _ in range(n)]
    s = [[0 for _ in range(n)] for _ in range(n)]
    for L in range(2, n):
        for i in range(1, n - L + 1):
            j = i + L - 1
            m[i][j] = sys.maxsize
            for k in range(i, j):
                q = m[i][k] + m[k+1][j] + p[i-1] * p[k] * p[j]
                if q < m[i][j]:
                    m[i][j] = q
                    s[i][j] = k

    return m, s
def print_optimal_parens(s, i, j):
    if i == j:
        return f"A{i}"
    else:
        return "(" + print_optimal_parens(s, i, s[i][j]) + \
               " x " + print_optimal_parens(s, s[i][j] + 1, j) + ")"
p = [5, 10, 3, 12, 5, 50, 6]
m, s = matrix_chain_order(p)

min_cost = m[1][len(p)-1]
optimal_order = print_optimal_parens(s, 1, len(p)-1)

print("Minimum number of multiplications:", min_cost)
print("Optimal parenthesization:", optimal_order)
naive_cost = 0
dims = p[:]
for i in range(1, len(dims)-1):
    naive_cost += dims[0] * dims[i] * dims[i+1]
    dims[0] = dims[0]
    dims[i+1] = dims[i+1]
print("Naive left-to-right cost:", naive_cost)
print("Multiplications saved:", naive_cost - min_cost)
# Out:
# Minimum number of multiplications: 2010
# Optimal parenthesization: ((A1 x A2) x ((A3 x A4) x (A5 x A6)))
# Naive left-to-right cost: 3380
# Multiplications saved: 1370
